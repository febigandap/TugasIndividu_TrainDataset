# %% [markdown]
# <a href="https://colab.research.google.com/github/febigandap/TugasIndividu_TrainDataset/blob/master/KESIMPULAN_%26_VISUALISASI_TrainDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KESIMPULAN**

# %% [markdown]
# DARI PROCESS YANG SUDAH DILAKUKAN DAPAT DIPEROLEH INFORMASI BAHWA
#
# **A.** JUMLAH PENUMPANG PADA CLASS **ECO** ADALAH :
#
# PENUMPANG LAKI-LAKI YANG SATISFIED : **4314**
#
# PENUMPANG LAKI-LAKI YANG DISSATISFIED/NEUTRAL : **18573**
#
# PENUMPANG WANITA YANG SATISFIED : **4387**
#
# PENUMPANG WANITA YANG DISSATISFIED/NEUTRAL : **19471**
#
# **B.** JUMLAH PENUMPANG PADA CLASS **ECO PLUS** ADALAH :
#
# PENUMPANG LAKI-LAKI YANG SATISFIED : **914**
#
# PENUMPANG LAKI-LAKI YANG DISSATISFIED/NEUTRAL : **2638**
#
# PENUMPANG WANITA YANG SATISFIED : **930**
#
# PENUMPANG WANITA YANG DISSATISFIED/NEUTRAL : **3012**
#
# **C.** JUMLAH PENUMPANG PADA CLASS **BUSINESS** ADALAH :
#
# PENUMPANG LAKI-LAKI YANG SATISFIED : **17263**
#
# PENUMPANG LAKI-LAKI YANG DISSATISFIED/NEUTRAL : **7475**
#
# PENUMPANG WANITA YANG SATISFIED : **17217**
#
# PENUMPANG WANITA YANG DISSATISFIED/NEUTRAL : **7710**

# %% [markdown]
# **VISUALISASI DATA DENGAN MODEL PIE**

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.style.use("classic")

slices = [4314, 18573, 4387, 19471, 914, 2638, 930, 3012, 17263, 7475, 17217, 7710]
labels = ['Male(Satisfied)', 'Male(DisS/Neutral)', 'Female(Satisfied)', 'Female(DisS/Neutral)',
          'Male(Satisfied)', 'Male(DisS/Neutral)', 'Female(Satisfied)', 'Female(DisS/Neutral)',
          'Male(Satisfied)', 'Male(DisS/Neutral)', 'Female(Satisfied)', 'Female(DisS/Neutral)',]
colors = ['#008fd5','#008fd5', '#008fd5', '#008fd5',
          '#fc4f30','#fc4f30', '#fc4f30', '#fc4f30', 
          "#6d904f", "#6d904f", "#6d904f", "#6d904f"]
explode = [0, 0, 0, 0,
           0.8, 0.8, 0.8, 0.8,
           0, 0, 0, 0]

plt.pie(slices, labels=labels, colors=colors, explode=explode, shadow=True, autopct='%1.1f%%',
         wedgeprops = {'edgecolor': 'black'})
plt.title("Penumpang Tiap Class Base on (Gender) and (satisfaction)")
plt.tight_layout()
plt.show()

# %% [markdown]
# KETERANGAN WARNA PIE BAR
#
# **BLUE = CLASS ECO**
#
# **RED = CLASS ECO PLUS**
#
# **GREEN = CLASS BUSINESS**
